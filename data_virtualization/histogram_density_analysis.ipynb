# %% [markdown]
# # Histogram & Density Analysis

# %%
import seaborn as sns

# %%
#Loading dataset from Seaborn Library
diamonds = sns.load_dataset('diamonds')

# %%
#Creating a copy df to create work file
#from diamonds dataset to df variable
df = diamonds.copy()

# %%
#To see first 5 elements in Dataset
df.head()

# %%
#In this step, we're selecting `kde = False` for to create only histogram
sns.distplot(df.price, kde=False);

# %%
#To see all displot arguments
# ?sns.distplot
# Out:
# Signature:
# sns.distplot(
#     a=None,
#     bins=None,
#     hist=True,
#     kde=True,
#     rug=False,
#     fit=None,
#     hist_kws=None,
#     kde_kws=None,
#     rug_kws=None,
#     fit_kws=None,
#     color=None,
#     vertical=False,
#     norm_hist=False,
#     axlabel=None,
#     label=None,
#     ax=None,
#     x=None,
# )
# Docstring:
# DEPRECATED: Flexibly plot a univariate distribution of observations.
#
# .. warning::
#    This function is deprecated and will be removed in a future version.
#    Please adapt your code to use one of two new functions:
#
#    - :func:`displot`, a figure-level function with a similar flexibility
#      over the kind of plot to draw
#    - :func:`histplot`, an axes-level function for plotting histograms,
#      including with kernel density smoothing
#
# This function combines the matplotlib ``hist`` function (with automatic
# calculation of a good default bin size) with the seaborn :func:`kdeplot`
# ...
